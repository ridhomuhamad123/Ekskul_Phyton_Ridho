# %%
nilai = 5
if (nilai > 7):
    print ("kompeten")
else:
    print("tidak kompeten")
# Out:
# tidak kompeten

# %%
nilai = int(input("masukkan nilai :"))
if (nilai > 7):
    print ("kompeten")
else:
    print("tidak kompeten")
# Out:
# kompeten
# 9 lebih besar dari pada 7
